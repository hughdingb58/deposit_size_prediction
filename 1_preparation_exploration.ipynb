# %% [markdown]
# # Data preparation
#
# ## Table of Contents
# - [Data gathering](#gather)
# - [Initial data exploration](#explo-start)
#     - [FRED time series plots](#explo-fred)
#     - [FDIC distributions and outlier detection](#explo-fdic)
#     - [Merging FRED and FDIC data](#explo-merge)
#     - [Summary statistics](#explo-summary)
#     - [Correlation heatmap](#explo-corr)
# - [Saving data for analysis](#supervised)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from pyarrow.feather import read_feather, write_feather

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 50)

# %% [markdown]
# In banking, forecasting deposit movements helps to manage cash flows and inform lending and investing decisions. Our goal is specifically to forecast bank deposit size using key macroeconomic indicators and bank-level data.
#
# [Github repository](https://github.com/hughdingb58/deposit_size_prediction)

# %% [markdown]
# <a id="gather"></a>
# # Data gathering

# %%
# %run "gather_api_data.py"

# %%
# FRED data
econ = read_feather("fred_econ.feather")
econ.head()
# Out:
#         date        gdp    cpi  unemployment_rate  fed_fund_rate
# 0 2000-01-01  13878.147  168.8                4.0           5.45  \
# 1 2000-04-01  14130.908  171.3                3.8           6.02
# 2 2000-07-01  14145.312  172.8                4.0           6.54
# 3 2000-10-01  14229.765  174.0                3.9           6.51
# 4 2001-01-01  14183.120  175.1                4.2           5.98
#
#    treasury_10yr_constant_maturity_rate  private_domestic_investment
# 0                                  6.66                     2351.223  \
# 1                                  5.99                     2490.501
# 2                                  6.05                     2466.375
# 3                                  5.74                     2471.534
# 4                                  5.16                     2358.969
#
#    private_domestic_investment_excl_iva_ccadj  fed_govt_expenditures
# 0                                    2287.827               1866.308  \
# 1                                    2424.549               1908.645
# 2                                    2394.141               1918.617
# 3                                    2395.566               1938.796
# 4                                    2285.261               1982.626
#
#    state_local_govt_expenditures  net_exports_good_services  housing_starts
# 0                       1308.322                   -356.583          1636.0  \
# 1                       1331.564                   -362.501          1626.0
# 2                       1357.309                   -393.867          1463.0
# 3                       1382.641                   -411.343          1549.0
# 4                       1431.089                   -402.653          1600.0
#
#    new_one_family_houses_sold  case_shiller_us_national_home_price_index
# 0                       873.0                                    100.000  \
# 1                       841.0                                    102.540
# 2                       887.0                                    105.721
# 3                       933.0                                    107.728
# 4                       936.0                                    109.214
#
#    advance_real_retail_food_services_sales  industrial_production_index
# 0                                     -0.8                      91.4251  \
# 1                                     -1.6                      92.6838
# 2                                     -0.4                      92.8458
# 3                                     -0.2                      92.6418
# 4                                      0.8                      91.8903
#
#    disposable_personal_income  retail_food_services_sales
# 0                      9799.9                    158325.0  \
# 1                      9913.7                    158599.0
# 2                     10035.9                    157863.0
# 3                     10139.2                    159245.0
# 4                     10211.7                    158789.0
#
#    personal_savings_rate  umich_consumer_sentiment_index
# 0                    4.5                           112.0  \
# 1                    4.3                           109.2
# 2                    4.7                           108.3
# 3                    4.3                           105.8
# 4                    4.5                            94.7
#
#    household_debt_service_payments_pct_disposable_income
# 0                                          11.581974      \
# 1                                          11.727593
# 2                                          11.883636
# 3                                          12.072070
# 4                                          12.175219
#
#    credit_card_delinquency_rate
# 0                          4.43  \
# 1                          4.51
# 2                          4.53
# 3                          4.57
# 4                          4.81
#
#    consumer_credit_owned_securitized_outstanding
# 0                                     1538.52018  \
# 1                                     1570.52774
# 2                                     1629.75144
# 3                                     1684.59932
# 4                                     1729.85168
#
#    cpi_urban_consumers_less_food_energy
# 0                                 179.3  \
# 1                                 180.3
# 2                                 181.5
# 3                                 182.6
# 4                                 183.9
#
#    avg_hrly_earnings_production_nonsupervisory_employees
# 0                                              13.75      \
# 1                                              13.89
# 2                                              14.02
# 3                                              14.17
# 4                                              14.29
#
#    real_median_household_income  pce  total_vehicle_sales  year  quarter
# 0                       67470.0  NaN               18.635  2000        1
# 1                           NaN  NaN               17.939  2000        2
# 2                           NaN  NaN               17.316  2000        3
# 3                           NaN  NaN               17.514  2000        4
# 4                       66360.0  NaN               17.652  2001        1

# %% [markdown]
# FDIC data is read from its [API](https://banks.data.fdic.gov/docs/).

# %%
# FDIC data
financials = read_feather("fdic_financials.feather")
financials.head()
# Out:
#            name       date  year  quarter  total_assets
# 0  15 BEACH MHC 2022-03-31  2022        1        364211  \
# 1  15 BEACH MHC 2022-06-30  2022        2        365856
# 2  15 BEACH MHC 2022-09-30  2022        3        360641
# 3  15 BEACH MHC 2022-12-31  2022        4        356248
# 4  15 BEACH MHC 2023-03-31  2023        1        351115
#
#    total_interest_expense_quarterly  total_deposits
# 0                               988          295932  \
# 1                               952          298841
# 2                               964          291425
# 3                              1360          286909
# 4                              2144          281149
#
#    non_interest_expense_quarterly  debt_securities_maturity_1yr_or_less
# 0                            6660                                  4889  \
# 1                            6772                                  4095
# 2                            6900                                  5580
# 3                            8168                                  3447
# 4                            7204                                  7457
#
#    net_income_quarterly
# 0                   445
# 1                   581
# 2                   674
# 3                   384
# 4                   435

# %% [markdown]
# We set aside some bank rows for robustness checks later on.

# %%
# Get list of sample banks
rng = np.random.default_rng(0)
bank_sample = rng.choice(list(set(financials["name"])), size = 5, replace = False)
# Manually append a large and two medium banks
bank_sample_map = {
    "BANK OF AMERICA CORP": "large",
    "TORONTO-DOMINION BANK THE": "intermediate",
    "CHARLES SCHWAB CORP THE": "intermediate"
}
for bank in bank_sample:
    bank_sample_map[bank] = "small"
bank_sample = list(bank_sample) + list(bank_sample_map.keys())
bank_sample
# Out:
# ['MIDDLESEX BCORP MHC',
#  'MILLEDGEVILLE BCORP INC',
#  'SJN BANC CO',
#  'INDEPENDENT CMTY BCORP INC',
#  'DAINGERFIELD HOLDING CO',
#  'BANK OF AMERICA CORP',
#  'TORONTO-DOMINION BANK THE',
#  'CHARLES SCHWAB CORP THE',
#  'MIDDLESEX BCORP MHC',
#  'MILLEDGEVILLE BCORP INC',
#  'SJN BANC CO',
#  'INDEPENDENT CMTY BCORP INC',
#  'DAINGERFIELD HOLDING CO']

# %%
# Move these banks to their own df
financials_sample = financials[financials["name"].isin(bank_sample)]
financials = financials[~financials["name"].isin(bank_sample)]

# %% [markdown]
# <a id="explo-start"></a>
# # Initial data exploration

# %% [markdown]
# We first visualize the FDIC and FRED data separately, and then join them together to check for summary statistics and correlations.

# %% [markdown]
# <a id="explo-fred"></a>
# ## FRED time series plots

# %%
for indicator in econ.columns[1:-2]:
    plt.figure(figsize = (4, 3))
    ax = sns.lineplot(econ, x = "date", y = indicator)
    ax.set_title(indicator + " over time")
    ax.set_xlabel("")
    plt.show()

# %% [markdown]
# All FRED indicators appear to follow reasonable and expected trends over time (naturally with fluctuations during the 2020 pandemic), and there do not appear to be significant outliers.

# %% [markdown]
# <a id="explo-fdic"></a>
# ## FDIC distributions and outlier detection

# %% [markdown]
# We first plot a histogram of a proxy of our outcome variable, deposit size.

# %%
sns.histplot(financials, x = "total_deposits", bins = 100)
# Out:
# <Axes: xlabel='total_deposits', ylabel='Count'>

# %% [markdown]
# We see that the vast majority of banks have deposit sizes that are far smaller than the largest banks. However, since our analysis is from a macroeconomic perspective, we are interested in categories of banks rather than individual banks. We aggregate the banks into three equally weighted categories for large, intermediate, and small banks (based on [OCC categorizations](https://www.occ.gov/news-issuances/bulletins/2021/bulletin-2021-5.html)).

# %%
financials["total_assets_last"] = financials.groupby(
    ["name"]
)["total_assets"].transform("last")
financials["category"] = np.select(
    [financials["total_assets_last"] >= 2500000000,
     financials["total_assets_last"] >= 600000000],
    ["large", "intermediate"], default = "small"
)

financials.groupby(["category"]).agg({"total_assets_last": "sum"})
# Out:
#               total_assets_last
# category
# intermediate       532444389472
# large             1034669817588
# small             1052594156851

# %% [markdown]
# These thresholds seem reasonable (the three aggregate categories are comparably sized), so we will use them for now.

# %%
financials_agg = financials.drop(["name"], axis = 1). \
  groupby(["category", "date", "year", "quarter"]).agg("sum").reset_index(). \
  drop("total_assets_last", axis = 1)
financials_agg.head()
# Out:
#        category       date  year  quarter  total_assets
# 0  intermediate 2000-03-31  2000        1     558319105  \
# 1  intermediate 2000-06-30  2000        2     597203394
# 2  intermediate 2000-09-30  2000        3     619144497
# 3  intermediate 2000-12-31  2000        4     641096047
# 4  intermediate 2001-03-31  2001        1     730053169
#
#    total_interest_expense_quarterly  total_deposits
# 0                          20550976       367147508  \
# 1                          23254692       388896435
# 2                          26694724       394527160
# 3                          28115956       410358973
# 4                          29287200       479205515
#
#    non_interest_expense_quarterly  debt_securities_maturity_1yr_or_less
# 0                        24161608                              14341318  \
# 1                        24171144                              15556297
# 2                        25132440                              16135172
# 3                        25822732                              16514098
# 4                        29143224                              15717210
#
#    net_income_quarterly
# 0               2571182
# 1               2146797
# 2               2189389
# 3               2181289
# 4               2319569

# %% [markdown]
# Now that we have reduced our data to aggregate categories we are confident we are interested in, we generate histograms for each metric, each across a period of 6 years, to visually inspect for unusual distributions.

# %%
date_ranges = ["2000-01-01", "2006-01-01", "2012-01-01", "2018-01-01", "2024-01-01"]

desc_col_num = 4
fig, axes = plt.subplots(financials_agg.shape[1] - desc_col_num - 1,
                         len(date_ranges) - 1, figsize = (50, 100))

for i in range(1, len(date_ranges)):
    curr_data = financials_agg[(financials_agg["date"] >= date_ranges[i - 1]) &
                               (financials_agg["date"] < date_ranges[i])]
    for j in range(desc_col_num, financials_agg.shape[1] - 1):
        metric = financials_agg.columns[j]
        sns.histplot(curr_data, x = metric, bins = 10, ax = axes[j - desc_col_num, i - 1])
        axes[j - desc_col_num, i - 1].set_title(
            metric + ", " + date_ranges[i - 1] + " to " + date_ranges[i]
        )

# %% [markdown]
# The values seem to generally follow a very roughly normal distribution (with some skew at times), and the outliers do not seem too substantial. This matches what we would expect from the variables.

# %% [markdown]
# <a id="explo-merge"></a>
# ## Merging FRED and FDIC data

# %%
# Merge on quarter
df_full = pd.merge(econ.drop("date", axis = 1), financials_agg)
df_samples_full = pd.merge(econ.drop("date", axis = 1), financials_sample)
# Rearrange columns
cols = list(df_full.columns)
for col in ["total_deposits", "quarter", "year", "date", "category"]:
    cols.insert(0, cols.pop(cols.index(col)))
df_full = df_full[cols].sort_values(["date", "category"])
df_full.head()
# Out:
#        category       date  year  quarter  total_deposits        gdp    cpi
# 0  intermediate 2000-03-31  2000        1       367147508  13878.147  168.8  \
# 1         large 2000-03-31  2000        1       440860254  13878.147  168.8
# 2         small 2000-03-31  2000        1      1186649633  13878.147  168.8
# 3  intermediate 2000-06-30  2000        2       388896435  14130.908  171.3
# 4         large 2000-06-30  2000        2       453740157  14130.908  171.3
#
#    unemployment_rate  fed_fund_rate  treasury_10yr_constant_maturity_rate
# 0                4.0           5.45                                  6.66  \
# 1                4.0           5.45                                  6.66
# 2                4.0           5.45                                  6.66
# 3                3.8           6.02                                  5.99
# 4                3.8           6.02                                  5.99
#
#    private_domestic_investment  private_domestic_investment_excl_iva_ccadj
# 0                     2351.223                                    2287.827  \
# 1                     2351.223                                    2287.827
# 2                     2351.223                                    2287.827
# 3                     2490.501                                    2424.549
# 4                     2490.501                                    2424.549
#
#    fed_govt_expenditures  state_local_govt_expenditures
# 0               1866.308                       1308.322  \
# 1               1866.308                       1308.322
# 2               1866.308                       1308.322
# 3               1908.645                       1331.564
# 4               1908.645                       1331.564
#
#    net_exports_good_services  housing_starts  new_one_family_houses_sold
# 0                   -356.583          1636.0                       873.0  \
# 1                   -356.583          1636.0                       873.0
# 2                   -356.583          1636.0                       873.0
# 3                   -362.501          1626.0                       841.0
# 4                   -362.501          1626.0                       841.0
#
#    case_shiller_us_national_home_price_index
# 0                                     100.00  \
# 1                                     100.00
# 2                                     100.00
# 3                                     102.54
# 4                                     102.54
#
#    advance_real_retail_food_services_sales  industrial_production_index
# 0                                     -0.8                      91.4251  \
# 1                                     -0.8                      91.4251
# 2                                     -0.8                      91.4251
# 3                                     -1.6                      92.6838
# 4                                     -1.6                      92.6838
#
#    disposable_personal_income  retail_food_services_sales
# 0                      9799.9                    158325.0  \
# 1                      9799.9                    158325.0
# 2                      9799.9                    158325.0
# 3                      9913.7                    158599.0
# 4                      9913.7                    158599.0
#
#    personal_savings_rate  umich_consumer_sentiment_index
# 0                    4.5                           112.0  \
# 1                    4.5                           112.0
# 2                    4.5                           112.0
# 3                    4.3                           109.2
# 4                    4.3                           109.2
#
#    household_debt_service_payments_pct_disposable_income
# 0                                          11.581974      \
# 1                                          11.581974
# 2                                          11.581974
# 3                                          11.727593
# 4                                          11.727593
#
#    credit_card_delinquency_rate
# 0                          4.43  \
# 1                          4.43
# 2                          4.43
# 3                          4.51
# 4                          4.51
#
#    consumer_credit_owned_securitized_outstanding
# 0                                     1538.52018  \
# 1                                     1538.52018
# 2                                     1538.52018
# 3                                     1570.52774
# 4                                     1570.52774
#
#    cpi_urban_consumers_less_food_energy
# 0                                 179.3  \
# 1                                 179.3
# 2                                 179.3
# 3                                 180.3
# 4                                 180.3
#
#    avg_hrly_earnings_production_nonsupervisory_employees
# 0                                              13.75      \
# 1                                              13.75
# 2                                              13.75
# 3                                              13.89
# 4                                              13.89
#
#    real_median_household_income  pce  total_vehicle_sales  total_assets
# 0                       67470.0  NaN               18.635     558319105  \
# 1                       67470.0  NaN               18.635     673086924
# 2                       67470.0  NaN               18.635    1670949027
# 3                           NaN  NaN               17.939     597203394
# 4                           NaN  NaN               17.939     705410574
#
#    total_interest_expense_quarterly  non_interest_expense_quarterly
# 0                          20550976                        24161608  \
# 1                          16940052                        30717096
# 2                          59039100                        54422508
# 3                          23254692                        24171144
# 4                          20369112                        30386532
#
#    debt_securities_maturity_1yr_or_less  net_income_quarterly
# 0                              14341318               2571182
# 1                              11665710                993225
# 2                              47522913               5115689
# 3                              15556297               2146797
# 4                               9522279               2171850

# %%
cols_sample = cols.copy()
cols_sample[0] = "name"
df_samples_full = df_samples_full[cols_sample].sort_values(["date", "name"])
df_samples_full
# Out:
#                            name       date  year  quarter  total_deposits
# 0          BANK OF AMERICA CORP 2000-03-31  2000        1       738900876  \
# 1    INDEPENDENT CMTY BCORP INC 2000-03-31  2000        1           22766
# 2       MILLEDGEVILLE BCORP INC 2000-03-31  2000        1           32801
# 3                   SJN BANC CO 2000-03-31  2000        1           24757
# 4     TORONTO-DOMINION BANK THE 2000-03-31  2000        1         5374191
# ..                          ...        ...   ...      ...             ...
# 695  INDEPENDENT CMTY BCORP INC 2023-12-31  2023        4           61560
# 696         MIDDLESEX BCORP MHC 2023-12-31  2023        4         4922887
# 697     MILLEDGEVILLE BCORP INC 2023-12-31  2023        4          133498
# 698                 SJN BANC CO 2023-12-31  2023        4          196425
# 699   TORONTO-DOMINION BANK THE 2023-12-31  2023        4       334268615
#
#            gdp      cpi  unemployment_rate  fed_fund_rate
# 0    13878.147  168.800                4.0           5.45  \
# 1    13878.147  168.800                4.0           5.45
# 2    13878.147  168.800                4.0           5.45
# 3    13878.147  168.800                4.0           5.45
# 4    13878.147  168.800                4.0           5.45
# ..         ...      ...                ...            ...
# 695  22679.255  307.671                3.8           5.33
# 696  22679.255  307.671                3.8           5.33
# 697  22679.255  307.671                3.8           5.33
# 698  22679.255  307.671                3.8           5.33
# 699  22679.255  307.671                3.8           5.33
#
#      treasury_10yr_constant_maturity_rate  private_domestic_investment
# 0                                    6.66                     2351.223  \
# 1                                    6.66                     2351.223
# 2                                    6.66                     2351.223
# 3                                    6.66                     2351.223
# 4                                    6.66                     2351.223
# ..                                    ...                          ...
# 695                                  4.80                     4118.672
# 696                                  4.80                     4118.672
# 697                                  4.80                     4118.672
# 698                                  4.80                     4118.672
# 699                                  4.80                     4118.672
#
#      private_domestic_investment_excl_iva_ccadj  fed_govt_expenditures
# 0                                      2287.827               1866.308  \
# 1                                      2287.827               1866.308
# 2                                      2287.827               1866.308
# 3                                      2287.827               1866.308
# 4                                      2287.827               1866.308
# ..                                          ...                    ...
# 695                                         NaN               6465.591
# 696                                         NaN               6465.591
# 697                                         NaN               6465.591
# 698                                         NaN               6465.591
# 699                                         NaN               6465.591
#
#      state_local_govt_expenditures  net_exports_good_services  housing_starts
# 0                         1308.322                   -356.583          1636.0  \
# 1                         1308.322                   -356.583          1636.0
# 2                         1308.322                   -356.583          1636.0
# 3                         1308.322                   -356.583          1636.0
# 4                         1308.322                   -356.583          1636.0
# ..                             ...                        ...             ...
# 695                       3805.228                   -783.734          1376.0
# 696                       3805.228                   -783.734          1376.0
# 697                       3805.228                   -783.734          1376.0
# 698                       3805.228                   -783.734          1376.0
# 699                       3805.228                   -783.734          1376.0
#
#      new_one_family_houses_sold  case_shiller_us_national_home_price_index
# 0                         873.0                                    100.000  \
# 1                         873.0                                    100.000
# 2                         873.0                                    100.000
# 3                         873.0                                    100.000
# 4                         873.0                                    100.000
# ..                          ...                                        ...
# 695                       670.0                                    312.769
# 696                       670.0                                    312.769
# 697                       670.0                                    312.769
# 698                       670.0                                    312.769
# 699                       670.0                                    312.769
#
#      advance_real_retail_food_services_sales  industrial_production_index
# 0                                       -0.8                      91.4251  \
# 1                                       -0.8                      91.4251
# 2                                       -0.8                      91.4251
# 3                                       -0.8                      91.4251
# 4                                       -0.8                      91.4251
# ..                                       ...                          ...
# 695                                     -0.3                     102.5502
# 696                                     -0.3                     102.5502
# 697                                     -0.3                     102.5502
# 698                                     -0.3                     102.5502
# 699                                     -0.3                     102.5502
#
#      disposable_personal_income  retail_food_services_sales
# 0                        9799.9                    158325.0  \
# 1                        9799.9                    158325.0
# 2                        9799.9                    158325.0
# 3                        9799.9                    158325.0
# 4                        9799.9                    158325.0
# ..                          ...                         ...
# 695                     16847.8                    228767.0
# 696                     16847.8                    228767.0
# 697                     16847.8                    228767.0
# 698                     16847.8                    228767.0
# 699                     16847.8                    228767.0
#
#      personal_savings_rate  umich_consumer_sentiment_index
# 0                      4.5                           112.0  \
# 1                      4.5                           112.0
# 2                      4.5                           112.0
# 3                      4.5                           112.0
# 4                      4.5                           112.0
# ..                     ...                             ...
# 695                    4.0                            63.8
# 696                    4.0                            63.8
# 697                    4.0                            63.8
# 698                    4.0                            63.8
# 699                    4.0                            63.8
#
#      household_debt_service_payments_pct_disposable_income
# 0                                            11.581974      \
# 1                                            11.581974
# 2                                            11.581974
# 3                                            11.581974
# 4                                            11.581974
# ..                                                 ...
# 695                                           9.796931
# 696                                           9.796931
# 697                                           9.796931
# 698                                           9.796931
# 699                                           9.796931
#
#      credit_card_delinquency_rate
# 0                            4.43  \
# 1                            4.43
# 2                            4.43
# 3                            4.43
# 4                            4.43
# ..                            ...
# 695                          3.10
# 696                          3.10
# 697                          3.10
# 698                          3.10
# 699                          3.10
#
#      consumer_credit_owned_securitized_outstanding
# 0                                       1538.52018  \
# 1                                       1538.52018
# 2                                       1538.52018
# 3                                       1538.52018
# 4                                       1538.52018
# ..                                             ...
# 695                                     4998.25192
# 696                                     4998.25192
# 697                                     4998.25192
# 698                                     4998.25192
# 699                                     4998.25192
#
#      cpi_urban_consumers_less_food_energy
# 0                                  179.30  \
# 1                                  179.30
# 2                                  179.30
# 3                                  179.30
# 4                                  179.30
# ..                                    ...
# 695                                311.39
# 696                                311.39
# 697                                311.39
# 698                                311.39
# 699                                311.39
#
#      avg_hrly_earnings_production_nonsupervisory_employees
# 0                                                13.75      \
# 1                                                13.75
# 2                                                13.75
# 3                                                13.75
# 4                                                13.75
# ..                                                 ...
# 695                                              29.29
# 696                                              29.29
# 697                                              29.29
# 698                                              29.29
# 699                                              29.29
#
#      real_median_household_income      pce  total_vehicle_sales  total_assets
# 0                         67470.0      NaN               18.635    1210111802  \
# 1                         67470.0      NaN               18.635         40255
# 2                         67470.0      NaN               18.635         40782
# 3                         67470.0      NaN               18.635         29488
# 4                         67470.0      NaN               18.635       5722038
# ..                            ...      ...                  ...           ...
# 695                           NaN  15519.9               15.919        143039
# 696                           NaN  15519.9               15.919       6309403
# 697                           NaN  15519.9               15.919        178541
# 698                           NaN  15519.9               15.919        237689
# 699                           NaN  15519.9               15.919     403573152
#
#      total_interest_expense_quarterly  non_interest_expense_quarterly
# 0                            37204552                        33232424  \
# 1                                 716                            2832
# 2                                1464                            1084
# 3                                 956                             676
# 4                              237084                           53756
# ..                                ...                             ...
# 695                              3632                            6444
# 696                            127572                          123808
# 697                              4692                            2596
# 698                              4080                            6140
# 699                           8983596                         9464168
#
#      debt_securities_maturity_1yr_or_less  net_income_quarterly
# 0                                10868264               4134952
# 1                                       0                    82
# 2                                     639                   120
# 3                                     408                   120
# 4                                 4607669                  3518
# ..                                    ...                   ...
# 695                                     0                   144
# 696                                303244                 -1848
# 697                                  1156                   540
# 698                                  8121                   112
# 699                              15636760                504778
#
# [700 rows x 37 columns]

# %% [markdown]
# Next, we scale and center the metrics so that they are all treated equally when modelling. We apply the same scaling from the main dataset to our sample data that we use for robustness checks.

# %%
df = df_full.copy()
df_samples = df_samples_full.copy()
for i in df.columns[4:]:
    df_mean = np.mean(df[i])
    df_scale = np.max([np.nanmax(df[i]), np.nanmin(df[i]) * -1])
    df[i] = df[i] - df_mean
    df[i] = df[i] / df_scale

    df_samples[i] = df_samples[i] - df_mean
    df_samples[i] = df_samples[i] / df_scale
df.head()
# Out:
#        category       date  year  quarter  total_deposits       gdp       cpi
# 0  intermediate 2000-03-31  2000        1       -0.320320 -0.172706 -0.185839  \
# 1         large 2000-03-31  2000        1       -0.313688 -0.172706 -0.185839
# 2         small 2000-03-31  2000        1       -0.246587 -0.172706 -0.185839
# 3  intermediate 2000-06-30  2000        2       -0.318363 -0.161561 -0.177713
# 4         large 2000-06-30  2000        2       -0.312529 -0.161561 -0.177713
#
#    unemployment_rate  fed_fund_rate  treasury_10yr_constant_maturity_rate
# 0          -0.121974       0.560238                              0.509916  \
# 1          -0.121974       0.560238                              0.509916
# 2          -0.121974       0.560238                              0.509916
# 3          -0.135487       0.647394                              0.409316
# 4          -0.135487       0.647394                              0.409316
#
#    private_domestic_investment  private_domestic_investment_excl_iva_ccadj
# 0                    -0.152421                                   -0.065298  \
# 1                    -0.152421                                   -0.065298
# 2                    -0.152421                                   -0.065298
# 3                    -0.119436                                   -0.018563
# 4                    -0.119436                                   -0.018563
#
#    fed_govt_expenditures  state_local_govt_expenditures
# 0              -0.225582                      -0.285041  \
# 1              -0.225582                      -0.285041
# 2              -0.225582                      -0.285041
# 3              -0.220787                      -0.278933
# 4              -0.220787                      -0.278933
#
#    net_exports_good_services  housing_starts  new_one_family_houses_sold
# 0                   0.224295        0.146654                    0.125720  \
# 1                   0.224295        0.146654                    0.125720
# 2                   0.224295        0.146654                    0.125720
# 3                   0.218864        0.142254                    0.102682
# 4                   0.218864        0.142254                    0.102682
#
#    case_shiller_us_national_home_price_index
# 0                                  -0.245369  \
# 1                                  -0.245369
# 2                                  -0.245369
# 3                                  -0.237248
# 4                                  -0.237248
#
#    advance_real_retail_food_services_sales  industrial_production_index
# 0                                -0.086721                    -0.053355  \
# 1                                -0.086721                    -0.053355
# 2                                -0.086721                    -0.053355
# 3                                -0.151762                    -0.041245
# 4                                -0.151762                    -0.041245
#
#    disposable_personal_income  retail_food_services_sales
# 0                   -0.188762                   -0.105106  \
# 1                   -0.188762                   -0.105106
# 2                   -0.188762                   -0.105106
# 3                   -0.182477                   -0.103936
# 4                   -0.182477                   -0.103936
#
#    personal_savings_rate  umich_consumer_sentiment_index
# 0               -0.04043                        0.253748  \
# 1               -0.04043                        0.253748
# 2               -0.04043                        0.253748
# 3               -0.04668                        0.228748
# 4               -0.04668                        0.228748
#
#    household_debt_service_payments_pct_disposable_income
# 0                                           0.039778      \
# 1                                           0.039778
# 2                                           0.039778
# 3                                           0.050737
# 4                                           0.050737
#
#    credit_card_delinquency_rate
# 0                      0.143002  \
# 1                      0.143002
# 2                      0.143002
# 3                      0.154819
# 4                      0.154819
#
#    consumer_credit_owned_securitized_outstanding
# 0                                      -0.300376  \
# 1                                      -0.300376
# 2                                      -0.300376
# 3                                      -0.293972
# 4                                      -0.293972
#
#    cpi_urban_consumers_less_food_energy
# 0                             -0.166460  \
# 1                             -0.166460
# 2                             -0.166460
# 3                             -0.163249
# 4                             -0.163249
#
#    avg_hrly_earnings_production_nonsupervisory_employees
# 0                                          -0.209258      \
# 1                                          -0.209258
# 2                                          -0.209258
# 3                                          -0.204478
# 4                                          -0.204478
#
#    real_median_household_income  pce  total_vehicle_sales  total_assets
# 0                      -0.01463  NaN             0.120187     -0.339016  \
# 1                      -0.01463  NaN             0.120187     -0.330704
# 2                      -0.01463  NaN             0.120187     -0.258426
# 3                           NaN  NaN             0.088630     -0.336200
# 4                           NaN  NaN             0.088630     -0.328362
#
#    total_interest_expense_quarterly  non_interest_expense_quarterly
# 0                         -0.072211                       -0.281306  \
# 1                         -0.083578                       -0.265944
# 2                          0.048942                       -0.210391
# 3                         -0.063701                       -0.281284
# 4                         -0.072784                       -0.266718
#
#    debt_securities_maturity_1yr_or_less  net_income_quarterly
# 0                             -0.237312             -0.241584
# 1                             -0.248671             -0.276122
# 2                             -0.096449             -0.185889
# 3                             -0.232154             -0.250873
# 4                             -0.257770             -0.250324

# %%
df_samples.head()
# Out:
#                          name       date  year  quarter  total_deposits
# 0        BANK OF AMERICA CORP 2000-03-31  2000        1       -0.286872  \
# 1  INDEPENDENT CMTY BCORP INC 2000-03-31  2000        1       -0.353351
# 2     MILLEDGEVILLE BCORP INC 2000-03-31  2000        1       -0.353350
# 3                 SJN BANC CO 2000-03-31  2000        1       -0.353351
# 4   TORONTO-DOMINION BANK THE 2000-03-31  2000        1       -0.352869
#
#         gdp       cpi  unemployment_rate  fed_fund_rate
# 0 -0.172706 -0.185839          -0.121974       0.560238  \
# 1 -0.172706 -0.185839          -0.121974       0.560238
# 2 -0.172706 -0.185839          -0.121974       0.560238
# 3 -0.172706 -0.185839          -0.121974       0.560238
# 4 -0.172706 -0.185839          -0.121974       0.560238
#
#    treasury_10yr_constant_maturity_rate  private_domestic_investment
# 0                              0.509916                    -0.152421  \
# 1                              0.509916                    -0.152421
# 2                              0.509916                    -0.152421
# 3                              0.509916                    -0.152421
# 4                              0.509916                    -0.152421
#
#    private_domestic_investment_excl_iva_ccadj  fed_govt_expenditures
# 0                                   -0.065298              -0.225582  \
# 1                                   -0.065298              -0.225582
# 2                                   -0.065298              -0.225582
# 3                                   -0.065298              -0.225582
# 4                                   -0.065298              -0.225582
#
#    state_local_govt_expenditures  net_exports_good_services  housing_starts
# 0                      -0.285041                   0.224295        0.146654  \
# 1                      -0.285041                   0.224295        0.146654
# 2                      -0.285041                   0.224295        0.146654
# 3                      -0.285041                   0.224295        0.146654
# 4                      -0.285041                   0.224295        0.146654
#
#    new_one_family_houses_sold  case_shiller_us_national_home_price_index
# 0                     0.12572                                  -0.245369  \
# 1                     0.12572                                  -0.245369
# 2                     0.12572                                  -0.245369
# 3                     0.12572                                  -0.245369
# 4                     0.12572                                  -0.245369
#
#    advance_real_retail_food_services_sales  industrial_production_index
# 0                                -0.086721                    -0.053355  \
# 1                                -0.086721                    -0.053355
# 2                                -0.086721                    -0.053355
# 3                                -0.086721                    -0.053355
# 4                                -0.086721                    -0.053355
#
#    disposable_personal_income  retail_food_services_sales
# 0                   -0.188762                   -0.105106  \
# 1                   -0.188762                   -0.105106
# 2                   -0.188762                   -0.105106
# 3                   -0.188762                   -0.105106
# 4                   -0.188762                   -0.105106
#
#    personal_savings_rate  umich_consumer_sentiment_index
# 0               -0.04043                        0.253748  \
# 1               -0.04043                        0.253748
# 2               -0.04043                        0.253748
# 3               -0.04043                        0.253748
# 4               -0.04043                        0.253748
#
#    household_debt_service_payments_pct_disposable_income
# 0                                           0.039778      \
# 1                                           0.039778
# 2                                           0.039778
# 3                                           0.039778
# 4                                           0.039778
#
#    credit_card_delinquency_rate
# 0                      0.143002  \
# 1                      0.143002
# 2                      0.143002
# 3                      0.143002
# 4                      0.143002
#
#    consumer_credit_owned_securitized_outstanding
# 0                                      -0.300376  \
# 1                                      -0.300376
# 2                                      -0.300376
# 3                                      -0.300376
# 4                                      -0.300376
#
#    cpi_urban_consumers_less_food_energy
# 0                              -0.16646  \
# 1                              -0.16646
# 2                              -0.16646
# 3                              -0.16646
# 4                              -0.16646
#
#    avg_hrly_earnings_production_nonsupervisory_employees
# 0                                          -0.209258      \
# 1                                          -0.209258
# 2                                          -0.209258
# 3                                          -0.209258
# 4                                          -0.209258
#
#    real_median_household_income  pce  total_vehicle_sales  total_assets
# 0                      -0.01463  NaN             0.120187     -0.291806  \
# 1                      -0.01463  NaN             0.120187     -0.379454
# 2                      -0.01463  NaN             0.120187     -0.379454
# 3                      -0.01463  NaN             0.120187     -0.379455
# 4                      -0.01463  NaN             0.120187     -0.379042
#
#    total_interest_expense_quarterly  non_interest_expense_quarterly
# 0                         -0.019789                       -0.260049  \
# 1                         -0.136900                       -0.337921
# 2                         -0.136898                       -0.337925
# 3                         -0.136899                       -0.337926
# 4                         -0.136156                       -0.337802
#
#    debt_securities_maturity_1yr_or_less  net_income_quarterly
# 0                             -0.252056             -0.207356
# 1                             -0.298194             -0.297860
# 2                             -0.298191             -0.297859
# 3                             -0.298192             -0.297859
# 4                             -0.278633             -0.297785

# %% [markdown]
# <a id="explo-summary"></a>
# ## Summary statistics

# %%
df.describe()
# Out:
#                       date         year    quarter  total_deposits
# count                  288   288.000000  288.00000    2.880000e+02  \
# mean   2012-02-14 06:00:00  2011.500000    2.50000   -1.233581e-17
# min    2000-03-31 00:00:00  2000.000000    1.00000   -3.203198e-01
# 25%    2006-03-08 12:00:00  2005.750000    1.75000   -1.906452e-01
# 50%    2012-02-14 12:00:00  2011.500000    2.50000   -7.699465e-02
# 75%    2018-01-22 12:00:00  2017.250000    3.25000    1.622689e-01
# max    2023-12-31 00:00:00  2023.000000    4.00000    6.466471e-01
# std                    NaN     6.934236    1.11998    2.510621e-01
#
#                 gdp           cpi  unemployment_rate  fed_fund_rate
# count  2.880000e+02  2.880000e+02       2.880000e+02   2.880000e+02  \
# mean   6.167906e-17 -8.018277e-17       3.238150e-17  -1.233581e-17
# min   -1.727056e-01 -1.858389e-01      -1.625141e-01  -2.654498e-01
# 25%   -6.873859e-02 -8.776336e-02      -9.663570e-02  -2.520706e-01
# 50%   -2.205477e-02  1.838849e-03      -3.751408e-02  -1.079574e-01
# 75%    8.471090e-02  6.821170e-02       4.863457e-02   1.191068e-01
# max    2.153630e-01  2.655231e-01       6.077562e-01   7.269049e-01
# std    1.067343e-01  1.126674e-01       1.393428e-01   2.982432e-01
#
#        treasury_10yr_constant_maturity_rate  private_domestic_investment
# count                          2.880000e+02                 2.880000e+02  \
# mean                           3.700743e-17                -1.233581e-16
# min                           -3.969907e-01                -2.481841e-01
# 25%                           -1.695133e-01                -1.263974e-01
# 50%                           -2.762137e-02                -3.756510e-02
# 75%                            1.559372e-01                 1.219144e-01
# max                            5.099162e-01                 2.907406e-01
# std                            2.004881e-01                 1.462874e-01
#
#        private_domestic_investment_excl_iva_ccadj  fed_govt_expenditures
# count                                2.100000e+02           2.880000e+02  \
# mean                                -1.015061e-16          -1.233581e-17
# min                                 -2.304481e-01          -2.255817e-01
# 25%                                 -8.281140e-02          -1.301925e-01
# 50%                                  2.298831e-03          -9.399791e-03
# 75%                                  7.287038e-02           5.455541e-02
# max                                  1.526744e-01           5.630579e-01
# std                                  9.817336e-02           1.685615e-01
#
#        state_local_govt_expenditures  net_exports_good_services
# count                   2.880000e+02               2.880000e+02  \
# mean                    6.167906e-17               4.625929e-17
# min                    -2.850413e-01              -4.484679e-01
# 25%                    -1.410364e-01              -1.199432e-01
# 50%                    -2.027284e-02               4.338062e-02
# 75%                     1.006702e-01               8.511409e-02
# max                     3.711364e-01               2.242948e-01
# std                     1.704623e-01               1.442577e-01
#
#        housing_starts  new_one_family_houses_sold
# count    2.880000e+02                2.880000e+02  \
# mean    -6.167906e-18                6.167906e-18
# min     -3.628052e-01               -2.990461e-01
# 25%     -1.371123e-01               -1.654968e-01
# 50%      1.471073e-03               -4.562635e-02
# 75%      1.343351e-01                1.473182e-01
# max      4.269000e-01                4.972102e-01
# std      1.943953e-01                2.044111e-01
#
#        case_shiller_us_national_home_price_index
# count                               2.880000e+02  \
# mean                                7.401487e-17
# min                                -2.453688e-01
# 25%                                -1.054668e-01
# 50%                                -3.093737e-02
# 75%                                 5.945762e-02
# max                                 4.349064e-01
# std                                 1.630707e-01
#
#        advance_real_retail_food_services_sales  industrial_production_index
# count                             2.880000e+02                 2.880000e+02  \
# mean                              3.083953e-18                 5.551115e-17
# min                              -1.021680e+00                -1.190396e-01
# 25%                              -3.794038e-02                -4.134648e-02
# 50%                               1.084011e-02                 1.540373e-02
# 75%                               4.336043e-02                 4.143132e-02
# max                               5.718157e-01                 6.704714e-02
# std                               1.437629e-01                 4.831391e-02
#
#        disposable_personal_income  retail_food_services_sales
# count                2.880000e+02                2.880000e+02  \
# mean                -8.635068e-17               -4.317534e-17
# min                 -1.887618e-01               -1.159922e-01
# 25%                 -8.956839e-02               -7.404037e-02
# 50%                 -2.166622e-02               -2.177093e-02
# 75%                  8.644212e-02                5.078447e-02
# max                  2.700255e-01                2.184818e-01
# std                  1.182236e-01                9.346156e-02
#
#        personal_savings_rate  umich_consumer_sentiment_index
# count           2.880000e+02                    2.880000e+02  \
# mean            2.467162e-17                   -9.868649e-17
# min            -1.373047e-01                   -2.864304e-01
# 25%            -4.433594e-02                   -9.937686e-02
# 50%            -1.386719e-02                    2.562314e-02
# 75%             1.113281e-02                    9.080171e-02
# max             8.189453e-01                    2.537481e-01
# std             1.186567e-01                    1.195146e-01
#
#        household_debt_service_payments_pct_disposable_income
# count                                       2.880000e+02      \
# mean                                       -8.635068e-17
# min                                        -2.062952e-01
# 25%                                        -8.119554e-02
# 50%                                        -5.156830e-02
# 75%                                         9.725032e-02
# max                                         1.681785e-01
# std                                         9.870737e-02
#
#        credit_card_delinquency_rate
# count                    288.000000  \
# mean                       0.000000
# min                       -0.283881
# 25%                       -0.152788
# 50%                       -0.042374
# 75%                        0.155558
# max                        0.488645
# std                        0.186835
#
#        consumer_credit_owned_securitized_outstanding
# count                                   2.880000e+02  \
# mean                                   -7.401487e-17
# min                                    -3.003756e-01
# 25%                                    -1.390604e-01
# 50%                                    -5.820651e-02
# 75%                                     1.539715e-01
# max                                     3.918128e-01
# std                                     1.879871e-01
#
#        cpi_urban_consumers_less_food_energy
# count                          2.880000e+02  \
# mean                          -2.467162e-17
# min                           -1.664604e-01
# 25%                           -9.067123e-02
# 50%                           -1.266134e-02
# 75%                            7.325664e-02
# max                            2.577343e-01
# std                            1.080440e-01
#
#        avg_hrly_earnings_production_nonsupervisory_employees
# count                                       2.880000e+02      \
# mean                                       -1.110223e-16
# min                                        -2.092580e-01
# 25%                                        -1.195516e-01
# 50%                                        -1.038466e-02
# 75%                                         8.026061e-02
# max                                         3.212985e-01
# std                                         1.378521e-01
#
#        real_median_household_income           pce  total_vehicle_sales
# count                  6.900000e+01  2.040000e+02         2.880000e+02  \
# mean                   4.827057e-17  1.741526e-16         8.018277e-17
# min                   -6.728157e-02 -1.095365e-01        -3.242018e-01
# 25%                   -3.648284e-02 -8.149670e-02        -4.121609e-02
# 50%                   -2.344770e-02 -1.535097e-02         3.222531e-02
# 75%                    4.441172e-02  6.318368e-02         7.015322e-02
# max                    1.231338e-01  1.773146e-01         2.752541e-01
# std                    5.585274e-02  8.997110e-02         1.071896e-01
#
#        total_assets  total_interest_expense_quarterly
# count    288.000000                      2.880000e+02  \
# mean       0.000000                     -1.079383e-17
# min       -0.339016                     -1.192745e-01
# 25%       -0.191904                     -7.891729e-02
# 50%       -0.080916                     -4.616309e-02
# 75%        0.175882                      3.203405e-02
# max        0.620543                      8.630979e-01
# std        0.252372                      1.371321e-01
#
#        non_interest_expense_quarterly  debt_securities_maturity_1yr_or_less
# count                    2.880000e+02                          2.880000e+02  \
# mean                    -2.467162e-17                         -2.467162e-17
# min                     -2.813061e-01                         -2.931855e-01
# 25%                     -1.530590e-01                         -1.349557e-01
# 50%                     -6.408749e-02                         -3.792802e-02
# 75%                      1.929774e-01                          9.152620e-02
# max                      6.620723e-01                          7.018061e-01
# std                      2.047555e-01                          2.112545e-01
#
#        net_income_quarterly
# count            288.000000
# mean               0.000000
# min               -0.674782
# 25%               -0.179903
# 50%               -0.075264
# 75%                0.120254
# max                0.702138
# std                0.238562

# %% [markdown]
# The summary statistics per metric appear to be reasonable, and are not too skewed by outliers.

# %% [markdown]
# <a id="explo-corr"></a>
# ## Correlation heatmap

# %%
corr_columns = list(df.columns[6:])
sns.set(rc = {"figure.figsize": (10, 10)})
sns.heatmap(df[corr_columns].corr(), vmin = -1, vmax = 1, cmap="vlag").set_title(
    "Correlation between metrics"
)
plt.show()

# %% [markdown]
# As we can see, many metrics are highly correlated, which may create issues of collinearity. We will perform manual feature selection to accommodate for this.

# %% [markdown]
# <a id="supervised"></a>
# # Saving data for analysis

# %%
df_samples["category"] = df_samples["name"].map(bank_sample_map)

# %%
write_feather(df, "df_train.feather")
write_feather(df_samples, "df_samples.feather")

# %%
write_feather(df, "df_temp.feather")

# %%
df_samples[]
